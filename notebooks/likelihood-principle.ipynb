# %% [markdown]
# # Likelihood principle — starter notebook
#
# Replace this with your own code and plots. The blog post links here for reproducibility.
#
# Naming: use `notebooks/<slug>.ipynb` where `<slug>` matches `content/blog/<slug>/` or `content/personal/<slug>/`.
